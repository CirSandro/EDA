# %% [markdown]
# # Nettoyage et Importation des données
#
# Dans ce notebook, nous allons effectuer un nettoyage de nos données, que nous allons stocker dans des fichiers .csv, afin de pouvoir les importer dans les notebooks correspondants sans avoir trop de calculs ni de temps d'exécution excessif, ce qui pourrait causer des problèmes.

# %% [markdown]
# Nous avons choisi de nous concentrer sur les articles de sport liés à Amazon. Plus précisément, nous utiliserons les données issues du dataset 5-core, qui est beaucoup moins volumineux en mémoire, mais largement suffisant pour nos analyses (voire même excessif pour certaines parties).
#
# Nous allons donc importer ces données :

# %%
import pandas as pd
import gzip
import json

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('Sports_and_Outdoors_5.json.gz')
print(len(df))
df.head()
# Out:
# 2839940
#    overall  verified   reviewTime      reviewerID        asin    reviewerName  \
# 0      5.0      True   06 3, 2015  A180LQZBUWVOLF  0000032034      Michelle A
# 1      1.0      True   04 1, 2015   ATMFGKU5SVEYY  0000032034       Crystal R
# 2      5.0      True  01 13, 2015  A1QE70QBJ8U6ZG  0000032034  darla Landreth
# 3      5.0      True  12 23, 2014  A22CP6Z73MZTYU  0000032034        L. Huynh
# 4      4.0      True  12 15, 2014  A22L28G8NRNLLN  0000032034         McKenna
#
#                                           reviewText  \
# 0            What a spectacular tutu! Very slimming.
# 1  What the heck? Is this a tutu for nuns? I know...
# 2                  Exactly what we were looking for!
# 3  I used this skirt for a Halloween costume and ...
# 4  This is thick enough that you can't see throug...
#
#                                              summary  unixReviewTime style  \
# 0                                         Five Stars      1433289600   NaN
# 1                          Is this a tutu for nuns?!      1427846400   NaN
# 2                                         Five Stars      1421107200   NaN
# 3  I liked that the elastic waist didn't dig in (...      1419292800   NaN
# 4  This is thick enough that you can't see throug...      1418601600   NaN
#
#   vote image
# 0  NaN   NaN
# 1  NaN   NaN
# 2  NaN   NaN
# 3  NaN   NaN
# 4  NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2839940 entries, 0 to 2839939
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   overall         float64
#  1   verified        bool
#  2   reviewTime      object
#  3   reviewerID      object
#  4   asin            object
#  5   reviewerName    object
#  6   reviewText      object
#  7   summary         object
#  8   unixReviewTime  int64
#  9   style           object
#  10  vote            object
#  11  image           object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 262.7+ MB

# %% [markdown]
# On constate que nous disposons de plus de 2 500 000 données, ce qui est encore largement suffisant. Nous pouvons donc envisager de réduire ce nombre si nécessaire.
#
# Dans un premier temps, nous allons effectuer un nettoyage des données en conservant uniquement les achats vérifiés.

# %%
# enlever les non verifiés
df = df[df.verified == True]
len(df)
# Out:
# 2611805

# %% [markdown]
# Nos données sont en quantité relativement similaire.
#
# Nous allons maintenant conserver uniquement les colonnes qui nous intéressent pour la suite du projet, afin d'améliorer la lisibilité.

# %%
df = df[['overall', 'reviewerID', 'asin', 'reviewTime']]
df = df.rename(columns={'overall': 'rating', 'reviewerID': 'user', 'asin': 'item', 'reviewTime': 'reviewTime'})
df
# Out:
#          rating            user        item   reviewTime
# 0           5.0  A180LQZBUWVOLF  0000032034   06 3, 2015
# 1           1.0   ATMFGKU5SVEYY  0000032034   04 1, 2015
# 2           5.0  A1QE70QBJ8U6ZG  0000032034  01 13, 2015
# 3           5.0  A22CP6Z73MZTYU  0000032034  12 23, 2014
# 4           4.0  A22L28G8NRNLLN  0000032034  12 15, 2014
# ...         ...             ...         ...          ...
# 2839935     5.0  A3TN0U64HONOPB  B01HJGAJ9O   04 5, 2018
# 2839936     5.0   AJDQLM8PT3YWT  B01HJGAJ9O   03 1, 2018
# 2839937     5.0  A3QK5ZLRE2KHLL  B01HJHHBHG  03 17, 2018
# 2839938     5.0  A3VDML80KNR9QQ  B01HJHHBHG  10 28, 2017
# 2839939     5.0  A3ONWSRNZFNC3U  B01HJHHBHG  06 11, 2017
#
# [2611805 rows x 4 columns]

# %% [markdown]
# Nous pouvons maintenant analyser le nombre d'utilisateurs et de produits distincts dans notre dataset :

# %%
# Afficher stat de notre dataset
print(len(df['user'].unique()))
print(len(df['item'].unique()))
# Out:
# 329602
# 104043

# %% [markdown]
# Dans le but d'obtenir les notes de nos achats, nous allons également télécharger les données issues du dataset metadata.

# %%
import pandas as pd
import gzip
import json

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df2 = getDF('meta_Sports_and_Outdoors.json.gz')
df2
# Out:
#                                                  category tech1  \
# 0       [Sports & Outdoors, Sports & Fitness, Other Sp...
# 1       [Sports & Outdoors, Sports & Fitness, Other Sp...
# 2       [Sports & Outdoors, Sports & Fitness, Other Sp...
# 3       [Sports & Outdoors, Sports & Fitness, Other Sp...
# 4       [Sports & Outdoors, Sports & Fitness, Other Sp...
# ...                                                   ...   ...
# 962295  [Sports & Outdoors, Sports & Fitness, Golf, On...
# 962296  [Sports & Outdoors, Outdoor Recreation, Campin...
# 962297  [Sports & Outdoors, Outdoor Recreation, Access...
# 962298              [Sports & Outdoors, Sports & Fitness]
# 962299  [Sports & Outdoors, Sports & Fitness, Clothing...
#
#                                               description  \
# 0       [3 layers of super-soft polyester tulle can be...
# 1       [3 layers of super-soft polyester tulle can be...
# 2       [3 layers of super-soft polyester tulle can be...
# 3                                                  [TUtu]
# 4       [Dance tutu for girls ages 2-8 years. Perfect ...
# ...                                                   ...
# 962295                                                 []
# 962296                                                 []
# 962297                                                 []
# 962298           [2XU Women's Fitness Compression Tights]
# 962299  [At the gym, on the court, in the field or pou...
#
#                                                       fit  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 962295
# 962296
# 962297
# 962298
# 962299   class="a-normal a-align-center a-spacing-smal...
#
#                                                     title  \
# 0                  Adult Tutu Assorted Colors (Turquoise)
# 1                 Bububibi Adult Ballet Tutu Cheetah Pink
# 2                           Girls Ballet Tutu Neon Orange
# 3                        Girls Ballet Tutu Zebra Hot Pink
# 4                             Girls Ballet Tutu Neon Blue
# ...                                                   ...
# 962295  Aweoods Inverted Umbrella Windproof Reverse Fo...
# 962296  JXULE Outdoor Sports Camping Home First Aid Ki...
# 962297  T&amp;s Shell Catcher Beretta A400 Multitarget...
# 962298             2XU Women's Fitness Compression Tights
# 962299                  2XU Men's Core Compression Shorts
#
#                                                  also_buy tech2       brand  \
# 0                                                      []          BubuBibi
# 1                                                      []          BubuBibi
# 2                                            [B01MYHD3LV]           Unknown
# 3                                                      []              Tutu
# 4       [B009THXHPA, B00BEU1ZBI, B079PYLZTM, B00BEU1ZR...          Bububibi
# ...                                                   ...   ...         ...
# 962295                                                 []        eShops ltd
# 962296                                                 []
# 962297  [B001U9YK8I, B005NH4NQC, B003QYGUME, B007URNR9...               STS
# 962298  [B01BISC5UA, B00O5XUS6O, B01B2LUO38, B0751MMZ3...               2XU
# 962299  [B01BCM95MS, B00UA88HCA, B01N6Q4O73, B01MS6NKN...               2XU
#
#                                                   feature  \
# 0       [3 Layers - 100% Polyester Tulle, Hand Wash La...
# 1       [3 Layers - 100% Polyester Tulle, Hand Wash La...
# 2       [3 Layers - 100% Polyester Tulle, Hand Wash La...
# 3                                                  [Tutu]
# 4       [3 Layers - 100% Polyester Tulle, Hand Wash La...
# ...                                                   ...
# 962295                                                 []
# 962296                                                 []
# 962297                                                 []
# 962298  [62% Nylon / 38% Elastane (Invista LYCRA), Mad...
# 962299  [100% Other Fibers, Imported, BENEFITS: Compre...
#
#                                                      rank  \
# 0                  712,899 in Clothing, Shoes & Jewelry (
# 1                  712,899 in Clothing, Shoes & Jewelry (
# 2       [>#924,198 in Toys & Games (See Top 100 in Toy...
# 3                        1,314,199 in Sports & Outdoors (
# 4       [>#393,597 in Toys & Games (See Top 100 in Toy...
# ...                                                   ...
# 962295                     544,488 in Sports & Outdoors (
# 962296                   1,436,289 in Sports & Outdoors (
# 962297                     570,537 in Sports & Outdoors (
# 962298                      25,733 in Sports & Outdoors (
# 962299                      68,476 in Sports & Outdoors (
#
#                                                 also_view  \
# 0       [B071LQWQBQ, B00M14DG0O, B076GTTY9W, B07BSZ4GY...
# 1                                                      []
# 2       [B0152HBC52, B07C29WWV1, B01M0BIP9H, B00VXJHFR...
# 3                                            [0000013714]
# 4       [B009THXHPA, B079PYLZTM, B079PQPLT3, B00UP6A3R...
# ...                                                   ...
# 962295  [B06Y4Z11XM, B07C8GQR5Y, B071JL6JV8, B07C1DPWR...
# 962296                                                 []
# 962297  [B00VM87O3A, B001U9YK8I, B07GBG321Z, B07CTRPK4...
# 962298  [B01BISC5UA, B00O5XUS6O, B079P8JG52, B01B2LUO3...
# 962299  [B01BCM95MS, B01N6Q4O73, B01MS6NKNK, B00UA88HC...
#
#                                                  main_cat similar_item  \
# 0       <img src="https://images-na.ssl-images-amazon....
# 1       <img src="https://images-na.ssl-images-amazon....
# 2                                            Toys & Games
# 3                                       Sports & Outdoors
# 4                                            Toys & Games
# ...                                                   ...          ...
# 962295                                  Sports & Outdoors
# 962296                                  Sports & Outdoors
# 962297                                  Sports & Outdoors
# 962298                                  Sports & Outdoors
# 962299                                  Sports & Outdoors
#
#                                                      date            price  \
# 0       <div class="a-fixed-left-grid a-spacing-none">...           $11.80
# 1       <div class="a-fixed-left-grid a-spacing-none">...           $11.97
# 2                                                                    $5.70
# 3                                                                    $7.50
# 4                                                                    $6.54
# ...                                                   ...              ...
# 962295                                                              $49.99
# 962296
# 962297
# 962298                                                     $35.80 - $89.95
# 962299                                                     $52.10 - $69.95
#
#               asin                                           imageURL  \
# 0       0000032042                                                 []
# 1       0000032069                                                 []
# 2       0000031860                                                 []
# 3       0000031852                                                 []
# 4       0000031895                                                 []
# ...            ...                                                ...
# 962295  B01HJH3742  [https://images-na.ssl-images-amazon.com/image...
# 962296  B01HJGNPLI  [https://images-na.ssl-images-amazon.com/image...
# 962297  B01HJHHBHG                                                 []
# 962298  B01HJGIZ2W  [https://images-na.ssl-images-amazon.com/image...
# 962299  B01HJGAJ9O  [https://images-na.ssl-images-amazon.com/image...
#
#                                           imageURLHighRes  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 962295  [https://images-na.ssl-images-amazon.com/image...
# 962296  [https://images-na.ssl-images-amazon.com/image...
# 962297                                                 []
# 962298  [https://images-na.ssl-images-amazon.com/image...
# 962299  [https://images-na.ssl-images-amazon.com/image...
#
#                                                   details
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 962295  {'Shipping Weight:': '1.2 pounds (', 'ASIN: ':...
# 962296                           {'ASIN: ': 'B01HJGNPLI'}
# 962297  {'Shipping Weight:': '1 pounds', 'ASIN: ': 'B0...
# 962298  {'
#     Product Dimensions:
#     ': '3 x 2 x 12...
# 962299  {'
#     Product Dimensions:
#     ': '11 x 6 x 2...
#
# [962300 rows x 19 columns]

# %% [markdown]
# Nous souhaitons conserver uniquement les produits appartenant à notre catégorie :

# %%
df2 = df2[df2.main_cat == 'Sports & Outdoors']
len(df2)
# Out:
# 810640

# %% [markdown]
# Nous souhaitons conserver uniquement les colonnes correspondant à l'ID de l'article et à son prix, dans le but de fusionner nos deux datasets. Nous allons donc renommer nos colonnes et convertir la colonne des prix en float en supprimant le symbole dollar ainsi que les valeurs vides, qui indiquent un prix inconnu.

# %%
df2 = df2[['asin', 'price']]
df2 = df2.rename(columns={'asin': 'item'})
df2 = df2.dropna(subset=['price'])
df2 = df2[df2['price'] != '']
df2['price'] = df2['price'].str.replace('$', '')
df2['price'] = pd.to_numeric(df2['price'], errors='coerce')
df2 = df2.dropna(subset=['price'])
df2
# Out:
#               item  price
# 3       0000031852   7.50
# 6       0000012300   4.00
# 7       0000031909   6.94
# 9       0022320113  19.99
# 13      0692747222   9.97
# ...            ...    ...
# 962282  B01HJDGJ1E  10.99
# 962284  B01HJDDVYW  14.35
# 962289  B01HJGB038  78.00
# 962294  B01HJGDVEE   9.96
# 962295  B01HJH3742  49.99
#
# [289707 rows x 2 columns]

# %% [markdown]
# Dans le but de faciliter l'exécution du notebook, nous enregistrons nos données dans un fichier .csv, que nous téléchargerons lors de l'exécution.

# %%
# Enregirster le dataframe df2 en local
df2.to_csv('df2_temp.csv', index=False)

# %% [markdown]
# Nous revenons ainsi à notre dataset de base, que nous allons fusionner avec les notes de nos articles. De plus, nous allons supprimer les transactions pour lesquelles nous ne connaissons pas le prix.

# %%
df2 = pd.read_csv('df2_temp.csv')
df = pd.merge(df, df2, on='item')
df = df.dropna(subset=['price'])
df
# Out:
#          rating            user        item   reviewTime  price
# 0           5.0  A3QIWQM4HVNR0A  0971100764  07 16, 2016  12.96
# 1           5.0  A3QIWQM4HVNR0A  0971100764  07 16, 2016  12.96
# 2           5.0  A1M9XEAH62IUPW  0971100764   07 5, 2016  12.96
# 3           5.0  A2U7YP4MP7BICG  0971100764  03 25, 2016  12.96
# 4           2.0   AIFK4MYNSAW4D  0971100764  02 28, 2016  12.96
# ...         ...             ...         ...          ...    ...
# 1469998     2.0   AW46USVHC6394  B01HJ8YC0Y  08 11, 2018  18.99
# 1469999     5.0  A1HCLZ57P6O0YM  B01HJDGJ1E  09 11, 2018  10.99
# 1470000     3.0  A2QTOTWE5ZRCZK  B01HJDGJ1E  08 24, 2018  10.99
# 1470001     5.0  A2NJSBP40UVZJ8  B01HJDGJ1E  08 18, 2018  10.99
# 1470002     4.0  A2MYPVY0BJW6EQ  B01HJDZ34I  07 17, 2018  24.27
#
# [1470003 rows x 5 columns]

# %% [markdown]
# Voici ainsi les statistiques de nos données actuelles :

# %%
# Afficher stat de notre dataset
print(len(df))
print(len(df['user'].unique()))
print(len(df['item'].unique()))
# Out:
# 1470003
# 313220
# 50082

# %% [markdown]
# Nous constatons que nos données incluent des informations sur les dates d'achat. Nous allons donc transformer ces données en format datetime afin de pouvoir analyser les années d'achat.

# %%
df['reviewTime'] = pd.to_datetime(df['reviewTime'], format='%m %d, %Y')
df['reviewTime'].dt.year.value_counts().sort_index()
# Out:
# reviewTime
# 2003         4
# 2005        18
# 2006        64
# 2007       509
# 2008      1101
# 2009      2547
# 2010      6318
# 2011     15512
# 2012     36330
# 2013    111386
# 2014    184687
# 2015    321350
# 2016    383585
# 2017    290129
# 2018    116463
# Name: count, dtype: int64

# %% [markdown]
# On remarque que les années avant 2011 ont très peu de données par rapport à celles qui suivent. Nous allons donc les supprimer.

# %%
# garder uniquement les reviewTime Supérieur à l'année 2014
df = df[df['reviewTime'].dt.year >= 2011]
len(df)
# Out:
# 1459442

# %% [markdown]
# Ainsi, voici les statistiques de notre dataset final :

# %%
# Afficher stat de notre dataset
df = df[['rating', 'user', 'item', 'price']]
print(f'Nombre de transaction: {len(df)}')
print('Nombre de user:', len(df['user'].unique()))
print('Nombre de item:', len(df['item'].unique()))
# Out:
# Nombre de transaction: 1459442
# Nombre de user: 312284
# Nombre de item: 50075

# %% [markdown]
# Nous enregistrons ainsi nos données en local :

# %%
# Enregirster le dataframe df en local
df.to_csv('df.csv', index=False)
df
# Out:
#          rating            user        item  price
# 0           5.0  A3QIWQM4HVNR0A  0971100764  12.96
# 1           5.0  A3QIWQM4HVNR0A  0971100764  12.96
# 2           5.0  A1M9XEAH62IUPW  0971100764  12.96
# 3           5.0  A2U7YP4MP7BICG  0971100764  12.96
# 4           2.0   AIFK4MYNSAW4D  0971100764  12.96
# ...         ...             ...         ...    ...
# 1469998     2.0   AW46USVHC6394  B01HJ8YC0Y  18.99
# 1469999     5.0  A1HCLZ57P6O0YM  B01HJDGJ1E  10.99
# 1470000     3.0  A2QTOTWE5ZRCZK  B01HJDGJ1E  10.99
# 1470001     5.0  A2NJSBP40UVZJ8  B01HJDGJ1E  10.99
# 1470002     4.0  A2MYPVY0BJW6EQ  B01HJDZ34I  24.27
#
# [1459442 rows x 4 columns]
